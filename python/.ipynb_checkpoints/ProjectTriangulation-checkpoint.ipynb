# %%
# !cd ../ && mvn clean install
# Out:
# [INFO] Scanning for projects...
# [INFO]
# [INFO] -------------< org.example:ComputationalGeometryProjectV2 >-------------
# [INFO] Building ComputationalGeometryProjectV2 1.0-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ ComputationalGeometryProjectV2 ---
# [INFO] Deleting C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ ComputationalGeometryProjectV2 ---
# [WARNING] Using platform encoding (Cp1251 actually) to copy filtered resources, i.e. build is platform dependent!
# [INFO] Copying 0 resource
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:compile (default-compile) @ ComputationalGeometryProjectV2 ---
# [INFO] Changes detected - recompiling the module!
# [WARNING] File encoding has not been set, using platform encoding Cp1251, i.e. build is platform dependent!
# [INFO] Compiling 5 source files to C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\target\classes
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ ComputationalGeometryProjectV2 ---
# [WARNING] Using platform encoding (Cp1251 actually) to copy filtered resources, i.e. build is platform dependent!
# [INFO] skip non existing resourceDirectory C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\src\test\resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:testCompile (default-testCompile) @ ComputationalGeometryProjectV2 ---
# [INFO] Changes detected - recompiling the module!
# [WARNING] File encoding has not been set, using platform encoding Cp1251, i.e. build is platform dependent!
# [INFO] Compiling 1 source file to C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\target\test-classes
# [INFO]
# [INFO] --- maven-surefire-plugin:2.12.4:test (default-test) @ ComputationalGeometryProjectV2 ---
# [INFO] Surefire report directory: C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\target\surefire-reports
#
# -------------------------------------------------------
#  T E S T S
# -------------------------------------------------------
#
# Results :
#
# Tests run: 0, Failures: 0, Errors: 0, Skipped: 0
#
# [INFO]
# [INFO] --- maven-jar-plugin:3.1.0:jar (default-jar) @ ComputationalGeometryProjectV2 ---
# [INFO] Building jar: C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\target\triangulation.jar
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ ComputationalGeometryProjectV2 ---
# [INFO] Installing C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\target\triangulation.jar to C:\Users\Александр\.m2\repository\org\example\ComputationalGeometryProjectV2\1.0-SNAPSHOT\ComputationalGeometryProjectV2-1.0-SNAPSHOT.jar
# [INFO] Installing C:\Users\Александр\Desktop\ComputationalGeometryProjectV2\pom.xml to C:\Users\Александр\.m2\repository\org\example\ComputationalGeometryProjectV2\1.0-SNAPSHOT\ComputationalGeometryProjectV2-1.0-SNAPSHOT.pom
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  2.310 s
# [INFO] Finished at: 2022-09-07T16:45:42+03:00
# [INFO] ------------------------------------------------------------------------

# %%
from random import random,randint
import os
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon
import matplotlib.pyplot as plt

width = 3000000
height = 4000000
points_count=8
fname="points.txt"

filename="../python/"+fname
outputfile="../python/triangulation.txt"

points = []
triangles = []

def generateRandomPoints():
    global points,points_count,width,height,fname;
    points = [[randint(1,width-1),randint(1,height-1)] for x in range(points_count)]
    with open(fname,"w+") as f:
        for p in points:
            f.write(" ".join(map(lambda x: "%.3f"%x,p)));
            f.write("\n")

def runTriangulationAlgorithm():
    global filename,outputfile;
    global points,points_count,width,height,fname;
    cmd="cd ../target/ && java -jar triangulation.jar %d %d %s %s"%(width,height,filename,outputfile)
    #print(cmd)
    assert os.system(cmd)==0


def parseTriangles():
    global triangles;
    triangles = []

    with open(outputfile,"r") as f:
        for line in f.readlines():
            t = list(map(float,line.split()))
            triangle = [
                [t[1],t[0]],
                [t[3],t[2]],
                [t[5],t[4]]
            ]
            triangles.append(triangle)

def drawTriangulation():
    global points,points_count,width,height,fname;
    global triangles;
    triangles = np.array(triangles,dtype=float);
    fig, ax = plt.subplots(1,1);
    for t in triangles:
        polygon = Polygon(t,edgecolor="red",facecolor="none")
        ax.add_patch(polygon)
        plt.scatter(t[:,0],t[:,1],s=20,color="blue")
    plt.ylim(0,height)
    plt.xlim(0,width)
    plt.show()

def processEverything():
    generateRandomPoints()
    runTriangulationAlgorithm()
    parseTriangles()
    drawTriangulation()

# %%
for i in range(10):
    processEverything()

# %%
# !cd ../target/ && java -jar triangulation.jar 3000000 4000000 ../python/points.txt ../python/triangulation.txt true
# Out:
# add: Point2D{x=2944035.0, y=444198.0}
# v3: Point2D{x=2944035.0, y=-3555802.0}
#
#
# 81.41989193235213
# 82.80872236630438
# Point2D{x=620392.0, y=151013.0}
# added
#
#
# 82.80872236630438
# -7.180922411239067
# Point2D{x=3000000.0, y=0.0}
# added
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=620392.0, y=151013.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=620392.0, y=151013.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=1077558.0, y=611119.0}
# v3: Point2D{x=1077558.0, y=-3388881.0}
#
#
# 60.440985174251935
# 44.81635870827519
# Point2D{x=620392.0, y=151013.0}
# removed
#
#
# 60.440985174251935
# -84.88957352568457
# Point2D{x=2944035.0, y=444198.0}
# added
#
#
# -84.88957352568457
# -72.36522467914375
# Point2D{x=3000000.0, y=0.0}
# added
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=620392.0, y=151013.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=1077558.0, y=611119.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=62157.0, y=1843526.0}
# v3: Point2D{x=62157.0, y=-2156474.0}
#
#
# 1.9310740323866455
# -39.48568789176801
# Point2D{x=1077558.0, y=611119.0}
# added
#
#
# -39.48568789176801
# -64.100591559532
# Point2D{x=2944035.0, y=444198.0}
# removed
#
#
# -64.100591559532
# -57.89131582541722
# Point2D{x=3000000.0, y=0.0}
# added
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=1077558.0, y=611119.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=2574622.0, y=1895762.0}
# v3: Point2D{x=2574622.0, y=-2104238.0}
#
#
# 53.634805372969176
# 88.80895008752076
# Point2D{x=62157.0, y=1843526.0}
# added
#
#
# 88.80895008752076
# -14.27827771635009
# Point2D{x=2944035.0, y=444198.0}
# added
#
#
# -14.27827771635009
# -12.646766526977217
# Point2D{x=3000000.0, y=0.0}
# added
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=2574622.0, y=1895762.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=2800416.0, y=2180080.0}
# v3: Point2D{x=2800416.0, y=-1819920.0}
#
#
# 52.09980095966153
# 82.99303131203799
# Point2D{x=62157.0, y=1843526.0}
# added
#
#
# 82.99303131203799
# 38.455199472179615
# Point2D{x=2574622.0, y=1895762.0}
# removed
#
#
# 82.99303131203799
# -4.7296207768351906
# Point2D{x=2944035.0, y=444198.0}
# added
#
#
# -4.7296207768351906
# -5.230786618771617
# Point2D{x=3000000.0, y=0.0}
# removed
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=2574622.0, y=1895762.0}, Point2D{x=2944035.0, y=444198.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=981015.0, y=2593121.0}
# v3: Point2D{x=981015.0, y=-1406879.0}
#
#
# 20.72235190172171
# 50.79278467213478
# Point2D{x=62157.0, y=1843526.0}
# added
#
#
# 50.79278467213478
# -77.20948616501818
# Point2D{x=2800416.0, y=2180080.0}
# added
#
#
# -77.20948616501818
# -37.9040635130313
# Point2D{x=3000000.0, y=0.0}
# added
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=981015.0, y=2593121.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=2524459.0, y=2906143.0}
# v3: Point2D{x=2524459.0, y=-1093857.0}
#
#
# 40.97963924728912
# 66.65717981841098
# Point2D{x=62157.0, y=1843526.0}
# added
#
#
# 66.65717981841098
# 78.53548098341136
# Point2D{x=981015.0, y=2593121.0}
# added
#
#
# 78.53548098341136
# -20.810449715943662
# Point2D{x=2800416.0, y=2180080.0}
# added
#
#
# -20.810449715943662
# -9.293122870810976
# Point2D{x=3000000.0, y=0.0}
# added
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=981015.0, y=2593121.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=981015.0, y=2593121.0}, Point2D{x=2524459.0, y=2906143.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=0.0, y=4000000.0}
# v3: Point2D{x=0.0, y=0.0}
#
#
# 0.0
# -1.6510043791403746
# Point2D{x=62157.0, y=1843526.0}
# added
#
#
# -1.6510043791403746
# -34.88801656664651
# Point2D{x=981015.0, y=2593121.0}
# removed
#
#
# -34.88801656664651
# -66.57274477826888
# Point2D{x=2524459.0, y=2906143.0}
# removed
#
#
# -66.57274477826888
# -56.981172516134905
# Point2D{x=2800416.0, y=2180080.0}
# added
#
#
# -56.981172516134905
# -36.86989764584405
# Point2D{x=3000000.0, y=0.0}
# added
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=62157.0, y=1843526.0}, Point2D{x=981015.0, y=2593121.0}, Point2D{x=2524459.0, y=2906143.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=0.0, y=4000000.0}, Point2D{x=2524459.0, y=2906143.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
#
#
#
# add: Point2D{x=3000000.0, y=4000000.0}
# v3: Point2D{x=3000000.0, y=0.0}
#
#
# 36.86989764584402
# 90.0
# Point2D{x=0.0, y=4000000.0}
# added
#
#
# 90.0
# 23.49640708524904
# Point2D{x=2524459.0, y=2906143.0}
# removed
#
#
# 90.0
# 6.258410122897755
# Point2D{x=2800416.0, y=2180080.0}
# removed
#
#
# 90.0
# 0.0
# Point2D{x=3000000.0, y=0.0}
# removed
# hull: [Point2D{x=0.0, y=0.0}, Point2D{x=0.0, y=4000000.0}, Point2D{x=2524459.0, y=2906143.0}, Point2D{x=2800416.0, y=2180080.0}, Point2D{x=3000000.0, y=0.0}]
# updated convex hull: [Point2D{x=0.0, y=0.0}, Point2D{x=0.0, y=4000000.0}]
#
#
#
# [Point2D{x=0.0, y=0.0}, Point2D{x=0.0, y=4000000.0}]
# executed successfully
